# %%
print('Welcome to Pandas 5')
# Out:
# Welcome to Pandas 5

# %%
import numpy as np
import pandas as pd

# %%
movies = pd.read_csv('movies.csv', index_col=0)
directors=pd.read_csv('directors.csv', index_col=0)

# %%
data = movies.merge(directors, how='left', left_on='director_id', right_on='id')
data.drop(['director_id', 'id_y'], axis=1, inplace=True)

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1460                            The Last Waltz           7.9          64
# 1461                                    Clerks           7.4         755
# 1462                                   Rampage           6.0         131
# 1463                                   Slacker           6.4          77
# 1464                               El Mariachi           6.6         238
#
#       year month       day      director_name gender
# 0     2009   Dec  Thursday      James Cameron   Male
# 1     2007   May  Saturday     Gore Verbinski   Male
# 2     2015   Oct    Monday         Sam Mendes   Male
# 3     2012   Jul    Monday  Christopher Nolan   Male
# 4     2007   May   Tuesday          Sam Raimi   Male
# ...    ...   ...       ...                ...    ...
# 1460  1978   May    Monday    Martin Scorsese   Male
# 1461  1994   Sep   Tuesday        Kevin Smith   Male
# 1462  2009   Aug    Friday           Uwe Boll   Male
# 1463  1990   Jul    Friday  Richard Linklater   Male
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN
#
# [1465 rows x 12 columns]

# %%
data['budget'] = (data['budget']/1000000).round(2)
data['revenue'] = (data['revenue']/1000000).round(2)
data
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1460                            The Last Waltz           7.9          64
# 1461                                    Clerks           7.4         755
# 1462                                   Rampage           6.0         131
# 1463                                   Slacker           6.4          77
# 1464                               El Mariachi           6.6         238
#
#       year month       day      director_name gender
# 0     2009   Dec  Thursday      James Cameron   Male
# 1     2007   May  Saturday     Gore Verbinski   Male
# 2     2015   Oct    Monday         Sam Mendes   Male
# 3     2012   Jul    Monday  Christopher Nolan   Male
# 4     2007   May   Tuesday          Sam Raimi   Male
# ...    ...   ...       ...                ...    ...
# 1460  1978   May    Monday    Martin Scorsese   Male
# 1461  1994   Sep   Tuesday        Kevin Smith   Male
# 1462  2009   Aug    Friday           Uwe Boll   Male
# 1463  1990   Jul    Friday  Richard Linklater   Male
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN
#
# [1465 rows x 12 columns]

# %% [markdown]
# Function is applied to a single column. Hence, the input(can be assumed) is a pandas series.

# %%
def calc_exp(ser):
    ser = ser - ser.mean()
    return ser

# %%
## another way of writing the same above function
def calc_exp(ser):
    ser = ser - np.mean(ser)
    return ser

# %%
data.groupby('director_name')['budget'].transform(calc_exp)
# Out:
# 0       130.300000
# 1       141.857143
# 2       150.142857
# 3       124.375000
# 4       174.004545
#            ...
# 1460    -47.478947
# 1461    -11.976667
# 1462    -21.700000
# 1463    -10.890909
# 1464    -31.168750
# Name: budget, Length: 1465, dtype: float64

# %%
def exp_bool(df):
    df=np.where(df-df.mean()>0, True, False)
    return df

# %%
data.groupby('director_name')['budget'].transform(exp_bool)
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 1460    False
# 1461    False
# 1462    False
# 1463    False
# 1464    False
# Name: budget, Length: 1465, dtype: bool

# %%
np.mean(data['budget'])
# Out:
# 48.02294880546076

# %%
def calc_risky(df):
    df['risky'] = (df['budget'] - df['revenue'].mean()) >=0
    return df

# %%
data_risky = data.groupby('director_name').apply(calc_risky)
data_risky
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1460                            The Last Waltz           7.9          64
# 1461                                    Clerks           7.4         755
# 1462                                   Rampage           6.0         131
# 1463                                   Slacker           6.4          77
# 1464                               El Mariachi           6.6         238
#
#       year month       day      director_name gender  risky
# 0     2009   Dec  Thursday      James Cameron   Male  False
# 1     2007   May  Saturday     Gore Verbinski   Male  False
# 2     2015   Oct    Monday         Sam Mendes   Male  False
# 3     2012   Jul    Monday  Christopher Nolan   Male  False
# 4     2007   May   Tuesday          Sam Raimi   Male  False
# ...    ...   ...       ...                ...    ...    ...
# 1460  1978   May    Monday    Martin Scorsese   Male  False
# 1461  1994   Sep   Tuesday        Kevin Smith   Male  False
# 1462  2009   Aug    Friday           Uwe Boll   Male  False
# 1463  1990   Jul    Friday  Richard Linklater   Male  False
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN  False
#
# [1465 rows x 13 columns]

# %%
data_risky.loc[data_risky['risky'] == True]
# Out:
#        id_x  budget  popularity  revenue  \
# 7     43608   200.0         107   586.09
# 12    43614   380.0         135  1045.71
# 15    43618   200.0          37   310.67
# 20    43624   209.0          64   303.03
# 24    43630   210.0           3   459.36
# ...     ...     ...         ...      ...
# 1347  47224     5.0           7     3.26
# 1349  47229     5.0           3     4.84
# 1351  47233     5.0           6     0.00
# 1356  47263    15.0          10     0.00
# 1383  47453     3.5           4     0.00
#
#                                             title  vote_average  vote_count  \
# 7                               Quantum of Solace           6.1        2965
# 12    Pirates of the Caribbean: On Stranger Tides           6.4        4948
# 15                                     Robin Hood           6.2        1398
# 20                                     Battleship           5.5        2114
# 24                          X-Men: The Last Stand           6.3        3525
# ...                                           ...           ...         ...
# 1347                          The Sweet Hereafter           6.8         103
# 1349                         90 Minutes in Heaven           5.4          40
# 1351                                Light Sleeper           5.7          15
# 1356                           Dying of the Light           4.5         118
# 1383                  In the Name of the King III           3.3          19
#
#       year month        day   director_name gender  risky
# 7     2008   Oct   Thursday    Marc Forster   Male   True
# 12    2011   May   Saturday    Rob Marshall   Male   True
# 15    2010   May  Wednesday    Ridley Scott   Male   True
# 20    2012   Apr  Wednesday      Peter Berg   Male   True
# 24    2006   May  Wednesday    Brett Ratner   Male   True
# ...    ...   ...        ...             ...    ...    ...
# 1347  1997   May  Wednesday     Atom Egoyan   Male   True
# 1349  2015   Sep     Friday  Michael Polish   Male   True
# 1351  1992   Aug     Friday   Paul Schrader    NaN   True
# 1356  2014   Dec   Thursday   Paul Schrader    NaN   True
# 1383  2013   Dec     Friday        Uwe Boll   Male   True
#
# [131 rows x 13 columns]

# %%
data_risky.loc[data_risky['director_name']=='Marc Forster', ['budget','revenue']]
# Out:
#       budget  revenue
# 7      200.0   586.09
# 31     200.0   531.86
# 811     30.0    53.65
# 828     30.0     2.53
# 914     25.0   116.77
# 1033    20.0    73.28
# 1369     4.0    44.91
# 1438     0.5     0.00

# %%
data_risky.loc[data_risky['director_name']=='Marc Forster', ['budget','revenue']].mean()
# Out:
# budget      63.68750
# revenue    176.13625
# dtype: float64

# %%
data
# Out:
#        id_x  budget  popularity  revenue  \
# 0     43597  237.00         150  2787.97
# 1     43598  300.00         139   961.00
# 2     43599  245.00         107   880.67
# 3     43600  250.00         112  1084.94
# 4     43602  258.00         115   890.87
# ...     ...     ...         ...      ...
# 1460  48363    0.00           3     0.32
# 1461  48370    0.03          19     3.15
# 1462  48375    0.00           7     0.00
# 1463  48376    0.00           3     0.00
# 1464  48395    0.22          14     2.04
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# 4                                 Spider-Man 3           5.9        3576
# ...                                        ...           ...         ...
# 1460                            The Last Waltz           7.9          64
# 1461                                    Clerks           7.4         755
# 1462                                   Rampage           6.0         131
# 1463                                   Slacker           6.4          77
# 1464                               El Mariachi           6.6         238
#
#       year month       day      director_name gender
# 0     2009   Dec  Thursday      James Cameron   Male
# 1     2007   May  Saturday     Gore Verbinski   Male
# 2     2015   Oct    Monday         Sam Mendes   Male
# 3     2012   Jul    Monday  Christopher Nolan   Male
# 4     2007   May   Tuesday          Sam Raimi   Male
# ...    ...   ...       ...                ...    ...
# 1460  1978   May    Monday    Martin Scorsese   Male
# 1461  1994   Sep   Tuesday        Kevin Smith   Male
# 1462  2009   Aug    Friday           Uwe Boll   Male
# 1463  1990   Jul    Friday  Richard Linklater   Male
# 1464  1992   Sep    Friday   Robert Rodriguez    NaN
#
# [1465 rows x 12 columns]

# %%
data.loc[:, ['revenue', 'budget']]
# Out:
#       revenue  budget
# 0     2787.97  237.00
# 1      961.00  300.00
# 2      880.67  245.00
# 3     1084.94  250.00
# 4      890.87  258.00
# ...       ...     ...
# 1460     0.32    0.00
# 1461     3.15    0.03
# 1462     0.00    0.00
# 1463     0.00    0.00
# 1464     2.04    0.22
#
# [1465 rows x 2 columns]

# %%
data.loc[:, ['revenue', 'budget']].apply(np.sum, axis=0)
# Out:
# revenue    209867.04
# budget      70353.62
# dtype: float64

# %%
data.loc[:, ['revenue', 'budget']].apply(np.sum, axis=1)
# Out:
# 0       3024.97
# 1       1261.00
# 2       1125.67
# 3       1334.94
# 4       1148.87
#          ...
# 1460       0.32
# 1461       3.18
# 1462       0.00
# 1463       0.00
# 1464       2.26
# Length: 1465, dtype: float64

# %%
data.loc[:, ['revenue', 'budget', 'vote_average']].apply('max', axis=0)
# Out:
# revenue         2787.97
# budget           380.00
# vote_average       8.30
# dtype: float64

# %%
pfizer = pd.read_csv('Pfizer_1.csv')
pfizer
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# 12  17-10-2020  diltiazem hydrochloride  Temperature     20.0     19.0
# 13  17-10-2020  diltiazem hydrochloride     Pressure      3.0      4.0
# 14  17-10-2020      docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020      docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020   ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020   ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0       NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1       NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2      18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3      22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4       NaN     27.0      NaN       26     25.0     24.0     23.0        22
# 5       NaN      7.0      NaN        9     10.0     11.0     10.0         9
# 6      36.0     36.0     37.0       38     37.0     38.0     39.0        40
# 7      20.0     21.0     22.0       23     24.0     25.0     25.0        24
# 8       NaN     48.0     48.0       49     50.0     52.0     55.0        56
# 9       NaN     25.0     26.0       27     28.0     29.0     28.0        28
# 10     10.0      NaN     11.0       12     12.0     11.0      NaN        13
# 11     13.0      NaN     15.0       15     15.0     15.0      NaN        16
# 12     19.0     18.0     17.0       16     15.0      NaN     13.0        14
# 13      4.0      4.0      6.0        8      9.0      NaN      9.0        11
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 0       20.0        21
# 1       19.0        20
# 2       25.0        25
# 3       29.0        28
# 4       21.0        20
# 5        9.0        11
# 6        NaN        42
# 7        NaN        27
# 8       57.0        58
# 9       29.0        30
# 10      14.0        15
# 11      17.0        18
# 12      11.0        10
# 13      13.0        14
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
pd.Series([1,np.nan,2,np.nan,3])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    3.0
# dtype: float64

# %%
pd.Series([1,np.nan,2.0,None,3])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    3.0
# dtype: float64

# %%
df=pd.DataFrame({'12':[1,2,np.nan,3,np.nan], '13':[np.nan,23,np.nan,1,2]})

# %%
df
# Out:
#     12    13
# 0  1.0   NaN
# 1  2.0  23.0
# 2  NaN   NaN
# 3  3.0   1.0
# 4  NaN   2.0

# %%
df[df.isnull().any(axis=1)]
# Out:
#     12   13
# 0  1.0  NaN
# 2  NaN  NaN
# 4  NaN  2.0

# %%
# df[df.isnull(axis=1)]

# %%
def is_null(x): return sum(x.isnull())

# %%
df.apply(is_null, axis=1)
# Out:
# 0    1
# 1    0
# 2    2
# 3    0
# 4    1
# dtype: int64

# %%
df.isnull()
# Out:
#       12     13
# 0  False   True
# 1  False  False
# 2   True   True
# 3  False  False
# 4   True  False

# %%
df.isna()
# Out:
#       12     13
# 0  False   True
# 1  False  False
# 2   True   True
# 3  False  False
# 4   True  False

# %%
pd.isna
# Out:
# <function pandas.core.dtypes.missing.isna(obj)>

# %%
pd.isnull
# Out:
# <function pandas.core.dtypes.missing.isna(obj)>

# %%
pfizer.isna().sum?

# %%
pfizer.isna().sum()
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
pfizer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
pfizer.isna().count()
# Out:
# Date         18
# Drug_Name    18
# Parameter    18
# 1:30:00      18
# 2:30:00      18
# 3:30:00      18
# 4:30:00      18
# 5:30:00      18
# 6:30:00      18
# 7:30:00      18
# 8:30:00      18
# 9:30:00      18
# 10:30:00     18
# 11:30:00     18
# 12:30:00     18
# dtype: int64

# %%
pfizer.dropna()
# Out:
#           Date               Drug_Name    Parameter  1:30:00  2:30:00  \
# 14  17-10-2020     docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020     docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020  ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020  ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
pfizer.dropna(how='all')
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# 12  17-10-2020  diltiazem hydrochloride  Temperature     20.0     19.0
# 13  17-10-2020  diltiazem hydrochloride     Pressure      3.0      4.0
# 14  17-10-2020      docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020      docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020   ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020   ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0       NaN     21.0     21.0       22     23.0     21.0     22.0        20
# 1       NaN     11.0     13.0       14     16.0     16.0     24.0        18
# 2      18.0      NaN     17.0       18      NaN      NaN     23.0        23
# 3      22.0      NaN     22.0       23      NaN      NaN     27.0        26
# 4       NaN     27.0      NaN       26     25.0     24.0     23.0        22
# 5       NaN      7.0      NaN        9     10.0     11.0     10.0         9
# 6      36.0     36.0     37.0       38     37.0     38.0     39.0        40
# 7      20.0     21.0     22.0       23     24.0     25.0     25.0        24
# 8       NaN     48.0     48.0       49     50.0     52.0     55.0        56
# 9       NaN     25.0     26.0       27     28.0     29.0     28.0        28
# 10     10.0      NaN     11.0       12     12.0     11.0      NaN        13
# 11     13.0      NaN     15.0       15     15.0     15.0      NaN        16
# 12     19.0     18.0     17.0       16     15.0      NaN     13.0        14
# 13      4.0      4.0      6.0        8      9.0      NaN      9.0        11
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 0       20.0        21
# 1       19.0        20
# 2       25.0        25
# 3       29.0        28
# 4       21.0        20
# 5        9.0        11
# 6        NaN        42
# 7        NaN        27
# 8       57.0        58
# 9       29.0        30
# 10      14.0        15
# 11      17.0        18
# 12      11.0        10
# 13      13.0        14
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
pfizer.fillna(0)
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      0.0     17.0
# 3   15-10-2020      docetaxel injection     Pressure      0.0     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      0.0
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      0.0
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# 12  17-10-2020  diltiazem hydrochloride  Temperature     20.0     19.0
# 13  17-10-2020  diltiazem hydrochloride     Pressure      3.0      4.0
# 14  17-10-2020      docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020      docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020   ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020   ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 0       0.0     21.0     21.0       22     23.0     21.0     22.0        20
# 1       0.0     11.0     13.0       14     16.0     16.0     24.0        18
# 2      18.0      0.0     17.0       18      0.0      0.0     23.0        23
# 3      22.0      0.0     22.0       23      0.0      0.0     27.0        26
# 4       0.0     27.0      0.0       26     25.0     24.0     23.0        22
# 5       0.0      7.0      0.0        9     10.0     11.0     10.0         9
# 6      36.0     36.0     37.0       38     37.0     38.0     39.0        40
# 7      20.0     21.0     22.0       23     24.0     25.0     25.0        24
# 8       0.0     48.0     48.0       49     50.0     52.0     55.0        56
# 9       0.0     25.0     26.0       27     28.0     29.0     28.0        28
# 10     10.0      0.0     11.0       12     12.0     11.0      0.0        13
# 11     13.0      0.0     15.0       15     15.0     15.0      0.0        16
# 12     19.0     18.0     17.0       16     15.0      0.0     13.0        14
# 13      4.0      4.0      6.0        8      9.0      0.0      9.0        11
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 0       20.0        21
# 1       19.0        20
# 2       25.0        25
# 3       29.0        28
# 4       21.0        20
# 5        9.0        11
# 6        0.0        42
# 7        0.0        27
# 8       57.0        58
# 9       29.0        30
# 10      14.0        15
# 11      17.0        18
# 12      11.0        10
# 13      13.0        14
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
pfizer.fillna?

# %%
pd.melt(pfizer, 
       id_vars=['Date', 'Drug_Name', 'Parameter'])
# Out:
#            Date                Drug_Name    Parameter  variable  value
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00   23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00   12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00    NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00    NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00   24.0
# ..          ...                      ...          ...       ...    ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00   14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00   23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00   28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00   24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00   15.0
#
# [216 rows x 5 columns]

# %%
pd.melt(pfizer, 
       id_vars=['Date', 'Drug_Name', 'Parameter'],
       var_name='Time',
       value_name='Result')
# Out:
#            Date                Drug_Name    Parameter      Time  Result
# 0    15-10-2020  diltiazem hydrochloride  Temperature   1:30:00    23.0
# 1    15-10-2020  diltiazem hydrochloride     Pressure   1:30:00    12.0
# 2    15-10-2020      docetaxel injection  Temperature   1:30:00     NaN
# 3    15-10-2020      docetaxel injection     Pressure   1:30:00     NaN
# 4    15-10-2020   ketamine hydrochloride  Temperature   1:30:00    24.0
# ..          ...                      ...          ...       ...     ...
# 211  17-10-2020  diltiazem hydrochloride     Pressure  12:30:00    14.0
# 212  17-10-2020      docetaxel injection  Temperature  12:30:00    23.0
# 213  17-10-2020      docetaxel injection     Pressure  12:30:00    28.0
# 214  17-10-2020   ketamine hydrochloride  Temperature  12:30:00    24.0
# 215  17-10-2020   ketamine hydrochloride     Pressure  12:30:00    15.0
#
# [216 rows x 5 columns]

# %%
df_melt = pd.melt(pfizer, 
       id_vars=['Date', 'Drug_Name', 'Parameter'],
       var_name='Time',
       value_name='Result')

# %%
df_melt.pivot(index=['Date', 'Drug_Name', 'Parameter'],
              columns='Time',
              values='Result')
# Out:
# Time                                            10:30:00  11:30:00  12:30:00  \
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure         18.0      19.0      20.0
#                                    Temperature      20.0      20.0      21.0
#            docetaxel injection     Pressure         26.0      29.0      28.0
#                                    Temperature      23.0      25.0      25.0
#            ketamine hydrochloride  Pressure          9.0       9.0      11.0
#                                    Temperature      22.0      21.0      20.0
# 16-10-2020 diltiazem hydrochloride Pressure         24.0       NaN      27.0
#                                    Temperature      40.0       NaN      42.0
#            docetaxel injection     Pressure         28.0      29.0      30.0
#                                    Temperature      56.0      57.0      58.0
#            ketamine hydrochloride  Pressure         16.0      17.0      18.0
#                                    Temperature      13.0      14.0      15.0
# 17-10-2020 diltiazem hydrochloride Pressure         11.0      13.0      14.0
#                                    Temperature      14.0      11.0      10.0
#            docetaxel injection     Pressure         28.0      29.0      28.0
#                                    Temperature      21.0      22.0      23.0
#            ketamine hydrochloride  Pressure         13.0      14.0      15.0
#                                    Temperature      22.0      23.0      24.0
#
# Time                                            1:30:00  2:30:00  3:30:00  \
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure        12.0     13.0      NaN
#                                    Temperature     23.0     22.0      NaN
#            docetaxel injection     Pressure         NaN     22.0     22.0
#                                    Temperature      NaN     17.0     18.0
#            ketamine hydrochloride  Pressure         8.0      NaN      NaN
#                                    Temperature     24.0      NaN      NaN
# 16-10-2020 diltiazem hydrochloride Pressure        18.0     19.0     20.0
#                                    Temperature     34.0     35.0     36.0
#            docetaxel injection     Pressure        23.0     24.0      NaN
#                                    Temperature     46.0     47.0      NaN
#            ketamine hydrochloride  Pressure        12.0     12.0     13.0
#                                    Temperature      8.0      9.0     10.0
# 17-10-2020 diltiazem hydrochloride Pressure         3.0      4.0      4.0
#                                    Temperature     20.0     19.0     19.0
#            docetaxel injection     Pressure        20.0     22.0     22.0
#                                    Temperature     12.0     13.0     14.0
#            ketamine hydrochloride  Pressure         8.0      9.0     10.0
#                                    Temperature     13.0     14.0     15.0
#
# Time                                            4:30:00  5:30:00  6:30:00  \
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure        11.0     13.0     14.0
#                                    Temperature     21.0     21.0     22.0
#            docetaxel injection     Pressure         NaN     22.0     23.0
#                                    Temperature      NaN     17.0     18.0
#            ketamine hydrochloride  Pressure         7.0      NaN      9.0
#                                    Temperature     27.0      NaN     26.0
# 16-10-2020 diltiazem hydrochloride Pressure        21.0     22.0     23.0
#                                    Temperature     36.0     37.0     38.0
#            docetaxel injection     Pressure        25.0     26.0     27.0
#                                    Temperature     48.0     48.0     49.0
#            ketamine hydrochloride  Pressure         NaN     15.0     15.0
#                                    Temperature      NaN     11.0     12.0
# 17-10-2020 diltiazem hydrochloride Pressure         4.0      6.0      8.0
#                                    Temperature     18.0     17.0     16.0
#            docetaxel injection     Pressure        22.0     22.0     23.0
#                                    Temperature     15.0     16.0     17.0
#            ketamine hydrochloride  Pressure        11.0     11.0     12.0
#                                    Temperature     16.0     17.0     18.0
#
# Time                                            7:30:00  8:30:00  9:30:00
# Date       Drug_Name               Parameter
# 15-10-2020 diltiazem hydrochloride Pressure        16.0     16.0     24.0
#                                    Temperature     23.0     21.0     22.0
#            docetaxel injection     Pressure         NaN      NaN     27.0
#                                    Temperature      NaN      NaN     23.0
#            ketamine hydrochloride  Pressure        10.0     11.0     10.0
#                                    Temperature     25.0     24.0     23.0
# 16-10-2020 diltiazem hydrochloride Pressure        24.0     25.0     25.0
#                                    Temperature     37.0     38.0     39.0
#            docetaxel injection     Pressure        28.0     29.0     28.0
#                                    Temperature     50.0     52.0     55.0
#            ketamine hydrochloride  Pressure        15.0     15.0      NaN
#                                    Temperature     12.0     11.0      NaN
# 17-10-2020 diltiazem hydrochloride Pressure         9.0      NaN      9.0
#                                    Temperature     15.0      NaN     13.0
#            docetaxel injection     Pressure        25.0     26.0     27.0
#                                    Temperature     18.0     19.0     20.0
#            ketamine hydrochloride  Pressure        12.0     11.0     12.0
#                                    Temperature     19.0     20.0     21.0

# %%
df_melt.pivot(index=['Date', 'Drug_Name'],
              columns=['Time', 'Parameter'],
              values='Result')
# Out:
# Time                                   1:30:00              2:30:00           \
# Parameter                          Temperature Pressure Temperature Pressure
# Date       Drug_Name
# 15-10-2020 diltiazem hydrochloride        23.0     12.0        22.0     13.0
#            docetaxel injection             NaN      NaN        17.0     22.0
#            ketamine hydrochloride         24.0      8.0         NaN      NaN
# 16-10-2020 diltiazem hydrochloride        34.0     18.0        35.0     19.0
#            docetaxel injection            46.0     23.0        47.0     24.0
#            ketamine hydrochloride          8.0     12.0         9.0     12.0
# 17-10-2020 diltiazem hydrochloride        20.0      3.0        19.0      4.0
#            docetaxel injection            12.0     20.0        13.0     22.0
#            ketamine hydrochloride         13.0      8.0        14.0      9.0
#
# Time                                   3:30:00              4:30:00           \
# Parameter                          Temperature Pressure Temperature Pressure
# Date       Drug_Name
# 15-10-2020 diltiazem hydrochloride         NaN      NaN        21.0     11.0
#            docetaxel injection            18.0     22.0         NaN      NaN
#            ketamine hydrochloride          NaN      NaN        27.0      7.0
# 16-10-2020 diltiazem hydrochloride        36.0     20.0        36.0     21.0
#            docetaxel injection             NaN      NaN        48.0     25.0
#            ketamine hydrochloride         10.0     13.0         NaN      NaN
# 17-10-2020 diltiazem hydrochloride        19.0      4.0        18.0      4.0
#            docetaxel injection            14.0     22.0        15.0     22.0
#            ketamine hydrochloride         15.0     10.0        16.0     11.0
#
# Time                                   5:30:00           ...     8:30:00  \
# Parameter                          Temperature Pressure  ... Temperature
# Date       Drug_Name                                     ...
# 15-10-2020 diltiazem hydrochloride        21.0     13.0  ...        21.0
#            docetaxel injection            17.0     22.0  ...         NaN
#            ketamine hydrochloride          NaN      NaN  ...        24.0
# 16-10-2020 diltiazem hydrochloride        37.0     22.0  ...        38.0
#            docetaxel injection            48.0     26.0  ...        52.0
#            ketamine hydrochloride         11.0     15.0  ...        11.0
# 17-10-2020 diltiazem hydrochloride        17.0      6.0  ...         NaN
#            docetaxel injection            16.0     22.0  ...        19.0
#            ketamine hydrochloride         17.0     11.0  ...        20.0
#
# Time                                            9:30:00             10:30:00  \
# Parameter                          Pressure Temperature Pressure Temperature
# Date       Drug_Name
# 15-10-2020 diltiazem hydrochloride     16.0        22.0     24.0        20.0
#            docetaxel injection          NaN        23.0     27.0        23.0
#            ketamine hydrochloride      11.0        23.0     10.0        22.0
# 16-10-2020 diltiazem hydrochloride     25.0        39.0     25.0        40.0
#            docetaxel injection         29.0        55.0     28.0        56.0
#            ketamine hydrochloride      15.0         NaN      NaN        13.0
# 17-10-2020 diltiazem hydrochloride      NaN        13.0      9.0        14.0
#            docetaxel injection         26.0        20.0     27.0        21.0
#            ketamine hydrochloride      11.0        21.0     12.0        22.0
#
# Time                                           11:30:00             12:30:00  \
# Parameter                          Pressure Temperature Pressure Temperature
# Date       Drug_Name
# 15-10-2020 diltiazem hydrochloride     18.0        20.0     19.0        21.0
#            docetaxel injection         26.0        25.0     29.0        25.0
#            ketamine hydrochloride       9.0        21.0      9.0        20.0
# 16-10-2020 diltiazem hydrochloride     24.0         NaN      NaN        42.0
#            docetaxel injection         28.0        57.0     29.0        58.0
#            ketamine hydrochloride      16.0        14.0     17.0        15.0
# 17-10-2020 diltiazem hydrochloride     11.0        11.0     13.0        10.0
#            docetaxel injection         28.0        22.0     29.0        23.0
#            ketamine hydrochloride      13.0        23.0     14.0        24.0
#
# Time
# Parameter                          Pressure
# Date       Drug_Name
# 15-10-2020 diltiazem hydrochloride     20.0
#            docetaxel injection         28.0
#            ketamine hydrochloride      11.0
# 16-10-2020 diltiazem hydrochloride     27.0
#            docetaxel injection         30.0
#            ketamine hydrochloride      18.0
# 17-10-2020 diltiazem hydrochloride     14.0
#            docetaxel injection         28.0
#            ketamine hydrochloride      15.0
#
# [9 rows x 24 columns]
